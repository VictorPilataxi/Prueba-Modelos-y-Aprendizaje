# %%
import numpy as np
from tensorflow import keras
from tensorflow.keras import layers
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
db = pd.read_csv("C:\\Users\\VICTOR\\Documents\\UIDE\\2 Modelos y Aprendizajes\\Prueba\\wdbc.data",encoding='latin-1')

# %%
db.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 32 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   No_Ident  569 non-null    int64
#  1   Dx        569 non-null    object
#  2   Ch1       569 non-null    float64
#  3   Ch2       569 non-null    float64
#  4   Ch3       569 non-null    float64
#  5   Ch4       569 non-null    float64
#  6   Ch5       569 non-null    float64
#  7   Ch6       569 non-null    float64
#  8   Ch7       569 non-null    float64
#  9   Ch8       569 non-null    float64
#  10  Ch9       569 non-null    float64
#  11  Ch10      569 non-null    float64
#  12  Ch11      569 non-null    float64
#  13  Ch12      569 non-null    float64
#  14  Ch13      569 non-null    float64
#  15  Ch14      569 non-null    float64
#  16  Ch15      569 non-null    float64
#  17  Ch16      569 non-null    float64
#  18  Ch17      569 non-null    float64
#  19  Ch18      569 non-null    float64
#  20  Ch19      569 non-null    float64
#  21  Ch20      569 non-null    float64
#  22  Ch21      569 non-null    float64
#  23  Ch22      569 non-null    float64
#  24  Ch23      569 non-null    float64
#  25  Ch24      569 non-null    float64
#  26  Ch25      569 non-null    float64
#  27  Ch26      569 non-null    float64
#  28  Ch27      569 non-null    float64
#  29  Ch28      569 non-null    float64
#  30  Ch29      569 non-null    float64
#  31  Ch30      569 non-null    float64
# dtypes: float64(30), int64(1), object(1)
# memory usage: 142.4+ KB

# %%
db.head()
# Out:
#    No_Ident Dx    Ch1    Ch2     Ch3     Ch4      Ch5      Ch6     Ch7  \
# 0    842517  M  20.57  17.77  132.90  1326.0  0.08474  0.07864  0.0869
# 1    842302  M  17.99  10.38  122.80  1001.0  0.11840  0.27760  0.3001
# 2  84300903  M  19.69  21.25  130.00  1203.0  0.10960  0.15990  0.1974
# 3  84348301  M  11.42  20.38   77.58   386.1  0.14250  0.28390  0.2414
# 4  84358402  M  20.29  14.34  135.10  1297.0  0.10030  0.13280  0.1980
#
#        Ch8  ...   Ch21   Ch22    Ch23    Ch24    Ch25    Ch26    Ch27    Ch28  \
# 0  0.07017  ...  24.99  23.41  158.80  1956.0  0.1238  0.1866  0.2416  0.1860
# 1  0.14710  ...  25.38  17.33  184.60  2019.0  0.1622  0.6656  0.7119  0.2654
# 2  0.12790  ...  23.57  25.53  152.50  1709.0  0.1444  0.4245  0.4504  0.2430
# 3  0.10520  ...  14.91  26.50   98.87   567.7  0.2098  0.8663  0.6869  0.2575
# 4  0.10430  ...  22.54  16.67  152.20  1575.0  0.1374  0.2050  0.4000  0.1625
#
#      Ch29     Ch30
# 0  0.2750  0.08902
# 1  0.4601  0.11890
# 2  0.3613  0.08758
# 3  0.6638  0.17300
# 4  0.2364  0.07678
#
# [5 rows x 32 columns]

# %%
db["Dx"] = db["Dx"].apply(lambda x:1 if x == "M" else 0)
db.head(30)
# Out:
#     No_Ident  Dx     Ch1    Ch2     Ch3     Ch4      Ch5      Ch6      Ch7  \
# 0     842517   1  20.570  17.77  132.90  1326.0  0.08474  0.07864  0.08690
# 1     842302   1  17.990  10.38  122.80  1001.0  0.11840  0.27760  0.30010
# 2   84300903   1  19.690  21.25  130.00  1203.0  0.10960  0.15990  0.19740
# 3   84348301   1  11.420  20.38   77.58   386.1  0.14250  0.28390  0.24140
# 4   84358402   1  20.290  14.34  135.10  1297.0  0.10030  0.13280  0.19800
# std    1.250206e+08    0.483918    3.524049    4.301036   24.298981
# min    8.670000e+03    0.000000    6.981000    9.710000   43.790000
# 25%    8.692180e+05    0.000000   11.700000   16.170000   75.170000
# 50%    9.060240e+05    0.000000   13.370000   18.840000   86.240000
# 75%    8.813129e+06    1.000000   15.780000   21.800000  104.100000
# max    9.113205e+08    1.000000   28.110000   39.280000  188.500000
#
#                Ch4         Ch5         Ch6         Ch7         Ch8  ...  \
# count   569.000000  569.000000  569.000000  569.000000  569.000000  ...
# mean    654.889104    0.096360    0.104341    0.088799    0.048919  ...
# std     351.914129    0.014064    0.052813    0.079720    0.038803  ...
# min     143.500000    0.052630    0.019380    0.000000    0.000000  ...
# 25%     420.300000    0.086370    0.064920    0.029560    0.020310  ...
# 50%     551.100000    0.095870    0.092630    0.061540    0.033500  ...
# 75%     782.700000    0.105300    0.130400    0.130700    0.074000  ...
# max    2501.000000    0.163400    0.345400    0.426800    0.201200  ...
#
#              Ch21        Ch22        Ch23         Ch24        Ch25  \
# count  569.000000  569.000000  569.000000   569.000000  569.000000
# mean    16.269190   25.677223  107.261213   880.583128    0.132369
# std      4.833242    6.146258   33.602542   569.356993    0.022832
# min      7.930000   12.020000   50.410000   185.200000    0.071170
# 25%     13.010000   21.080000   84.110000   515.300000    0.116600
# 50%     14.970000   25.410000   97.660000   686.500000    0.131300
# 75%     18.790000   29.720000  125.400000  1084.000000    0.146000
# max     36.040000   49.540000  251.200000  4254.000000    0.222600
#
#              Ch26        Ch27        Ch28        Ch29        Ch30
# count  569.000000  569.000000  569.000000  569.000000  569.000000
# mean     0.254265    0.272188    0.114606    0.290076    0.083946
# std      0.157336    0.208624    0.065732    0.061867    0.018061
# min      0.027290    0.000000    0.000000    0.156500    0.055040
# 25%      0.147200    0.114500    0.064930    0.250400    0.071460
# 50%      0.211900    0.226700    0.099930    0.282200    0.080040
# 75%      0.339100    0.382900    0.161400    0.317900    0.092080
# max      1.058000    1.252000    0.291000    0.663800    0.207500
#
# [8 rows x 32 columns]

# %%
corr = db.corr() 
plt.subplots(figsize=(20,15))
sns.heatmap(corr, annot = True)
# Out:
# <AxesSubplot: >

# %%
db.columns
# Out:
# Index(['No_Ident', 'Dx', 'Ch1', 'Ch2', 'Ch3', 'Ch4', 'Ch5', 'Ch6', 'Ch7',
#        'Ch8', 'Ch9', 'Ch10', 'Ch11', 'Ch12', 'Ch13', 'Ch14', 'Ch15', 'Ch16',
#        'Ch17', 'Ch18', 'Ch19', 'Ch20', 'Ch21', 'Ch22', 'Ch23', 'Ch24', 'Ch25',
#        'Ch26', 'Ch27', 'Ch28', 'Ch29', 'Ch30'],
#       dtype='object')

# %%
X = db[['No_Ident', 'Ch1', 'Ch2', 'Ch3', 'Ch4', 'Ch5', 'Ch6', 'Ch7',
       'Ch8', 'Ch9', 'Ch10', 'Ch11', 'Ch12', 'Ch13', 'Ch14', 'Ch15', 'Ch16',
       'Ch17', 'Ch18', 'Ch19', 'Ch20', 'Ch21', 'Ch22', 'Ch23', 'Ch24', 'Ch25',
       'Ch26', 'Ch27', 'Ch28', 'Ch29', 'Ch30']]
y = db[['Dx']]

# %%
X.head()
# Out:
#    No_Ident    Ch1    Ch2     Ch3     Ch4      Ch5      Ch6     Ch7      Ch8  \
# 0    842517  20.57  17.77  132.90  1326.0  0.08474  0.07864  0.0869  0.07017
# 1    842302  17.99  10.38  122.80  1001.0  0.11840  0.27760  0.3001  0.14710
# 2  84300903  19.69  21.25  130.00  1203.0  0.10960  0.15990  0.1974  0.12790
# 3  84348301  11.42  20.38   77.58   386.1  0.14250  0.28390  0.2414  0.10520
# 4  84358402  20.29  14.34  135.10  1297.0  0.10030  0.13280  0.1980  0.10430
#
#       Ch9  ...   Ch21   Ch22    Ch23    Ch24    Ch25    Ch26    Ch27    Ch28  \
# 0  0.1812  ...  24.99  23.41  158.80  1956.0  0.1238  0.1866  0.2416  0.1860
# 1  0.2419  ...  25.38  17.33  184.60  2019.0  0.1622  0.6656  0.7119  0.2654
# 2  0.2069  ...  23.57  25.53  152.50  1709.0  0.1444  0.4245  0.4504  0.2430
# 3  0.2597  ...  14.91  26.50   98.87   567.7  0.2098  0.8663  0.6869  0.2575
# 4  0.1809  ...  22.54  16.67  152.20  1575.0  0.1374  0.2050  0.4000  0.1625
#
#      Ch29     Ch30
# 0  0.2750  0.08902
# 1  0.4601  0.11890
# 2  0.3613  0.08758
# 3  0.6638  0.17300
# 4  0.2364  0.07678
#
# [5 rows x 31 columns]

# %%
y.head()
# Out:
#    Dx
# 0   1
# 1   1
# 2   1
# 3   1
# 4   1

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=2529)

#Shape of train test 
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((455, 31), (114, 31), (455, 1), (114, 1))

# %%
y.value_counts()
# Out:
# Dx
# 0     357
# 1     212
# dtype: int64

# %%
y.hist()
# Out:
# array([[<AxesSubplot: title={'center': 'Dx'}>]], dtype=object)

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import SGDClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier

from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# %%
def plot_confusion_matrix(X, y, model):
    y_pred = model.predict(X)
    cm = confusion_matrix(y, y_pred, labels=model.classes_)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm,
                                  display_labels=model.classes_)
    disp.plot()

    plt.show()

# %%
# Sin bucle plantilla basica
def evaluate_model(X_train, y_train, X_test, y_test, model):
    print(f"Error training: {(1 - model.score(X_train, y_train)) * 100} %")
    print(f"Error test: {(1 - model.score(X_test, y_test)) * 100} %")
    print("")
    print("")
    print("")


    print("Training confusion matrix")
    plot_confusion_matrix(X_train, y_train, model)
    print("Test confusion matrix")
    plot_confusion_matrix(X_test, y_test, model)

# %%
# KNN

model = KNeighborsClassifier(n_neighbors=5)
model.fit(X_train, y_train)

evaluate_model(X_train, y_train, X_test, y_test, model)
# Out:
# Error training: 16.043956043956044 %
# Error test: 19.298245614035093 %
#
#
#
# Training confusion matrix
# c:\Users\VICTOR\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\neighbors\_classification.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# Test confusion matrix

# %%
# Boosting
model = GradientBoostingClassifier(n_estimators=100, learning_rate=0.2,
    max_depth=1, random_state=0)

model = model.fit(X_train, y_train)

evaluate_model(X_train, y_train, X_test, y_test, model)
# Out:
# c:\Users\VICTOR\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\ensemble\_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Error training: 0.439560439560438 %
# Error test: 2.631578947368418 %
#
#
#
# Training confusion matrix
# Test confusion matrix

# %%
# Predict in original data:
X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, test_size=0.3, random_state=42)

# %%
evaluate_model(X_train, y_train, X_test, y_test, model)
# Out:
# Error training: 1.005025125628145 %
# Error test: 0.5847953216374324 %
#
#
#
# Training confusion matrix
# Test confusion matrix
